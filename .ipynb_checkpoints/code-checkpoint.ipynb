# %% [markdown]
# # Best Neighborhood in Pittsburgh
# ## Team High Five

# %% [markdown]
# ### Introduction
# All datasets are from WPRDC and we use two factors to decide the best neighborhood in Pittsburgh.
#
# Factors:
# * Crime rate
# * Median Age at Death
#
# We use three datasets:
# * Police Incident Blotter
# * Total Population
# * Median Age at Death
#
# A neighborhood has a higher crime rate indicate the area is not safe enough. No one wants to live a place has a lot of crime happens.
#
# People who live in a neighborhood with has higher median death age indicate that the neighborhood might have a good environment, public facilities, and good medical service. Because everyone wants to live longer.

# %% [markdown]
# ### The Metric
#
# #### Crime Rate
# we figure out the crime rate as total crimes divided by the total population.
#
# #### Median Age at Death

# %% [markdown]
# ### Conclusion
#
# #### The best neighborhood in Pittsburgh is

# %%
import pandas as pd
import numpy as np
import ssl
import geopandas as gpd
ssl._create_default_https_context = ssl._create_unverified_context
# %matplotlib inline
population = pd.read_csv("https://data.wprdc.org/dataset/5b18c198-474c-4723-b735-cc5220ad43cc/resource/82f29015-6905-4b1c-8300-afe9bb2231b3/download/total-population.csv")
deaths = pd.read_csv("https://data.wprdc.org/dataset/ee735209-4de7-4ea4-b446-bf0f0f6d9cb3/resource/c2e1500a-a12a-4e91-be94-76c6a892b7e2/download/nhoodmedianage20112015.csv",
                         parse_dates=True)

# %%
population = pd.read_csv("https://data.wprdc.org/dataset/5b18c198-474c-4723-b735-cc5220ad43cc/resource/82f29015-6905-4b1c-8300-afe9bb2231b3/download/total-population.csv")


deaths = pd.read_csv("https://data.wprdc.org/dataset/ee735209-4de7-4ea4-b446-bf0f0f6d9cb3/resource/c2e1500a-a12a-4e91-be94-76c6a892b7e2/download/nhoodmedianage20112015.csv",
                           parse_dates=True)
d = deaths[["NEIGHBORHOOD", "TOTALdeaths*", "TOTAL MD AGE AT DEATH"]]
total_deaths = d.drop([90, 91], axis = 0)


new_total_deaths = total_deaths.rename(index={'SAINT CLAIR': 'ST. CLAIR'})

sorted_total_deaths = new_total_deaths.sort_values('NEIGHBORHOOD')




pop = population.sort_values('Neighborhood')
only_pop = pop[["Estimate; Total"]]

# %%
# Out:
#                  NEIGHBORHOOD  TOTALdeaths*
# 18           ALLEGHENY CENTER          46.0
# 3              ALLEGHENY WEST           8.0
# 42                  ALLENTOWN         126.0
# 34                  ARLINGTON          96.0
# 7           ARLINGTON HEIGHTS          17.0
# 71                 BANKSVILLE         253.0
# 32          BEDFORD DWELLINGS          88.0
# 84                  BEECHVIEW         434.0
# 41                BELTZHOOVER         125.0
# 82                 BLOOMFIELD         394.0
# 17                      BLUFF          42.0
# 19                    BON AIR          51.0
# 86           BRIGHTON HEIGHTS         496.0
# 88                  BROOKLINE         750.0
# 14       CALIFORNIA-KIRKBRIDE          30.0
# 87                    CARRICK         678.0
# 44  CENTRAL BUSINESS DISTRICT         133.0
# 79      CENTRAL LAWRENCEVILLE         358.0
# 47          CENTRAL NORTHSIDE         147.0
# 20            CENTRAL OAKLAND          52.0
# 15             CHARTIERS CITY          35.0
# 1                     CHATEAU           2.0
# 57            CRAFTON HEIGHTS         187.0
# 62           CRAWFORD ROBERTS         202.0
# 45           DUQUESNE HEIGHTS         134.0
# 49             EAST ALLEGHENY         157.0
# 12              EAST CARNEGIE          27.0
# 54                 EAST HILLS         177.0
# 80               EAST LIBERTY         364.0
# 40                    ELLIOTT         121.0
# ..                        ...           ...
# 64                PERRY NORTH         205.0
# 72                PERRY SOUTH         259.0
# 53               POINT BREEZE         175.0
# 31         POINT BREEZE NORTH          87.0
# 30                POLISH HILL          85.0
# 13              REGENT SQUARE          28.0
# 21                  RIDGEMONT          52.0
# 4                 SAINT CLAIR          10.0
# 83                  SHADYSIDE         406.0
# 69                   SHERADEN         248.0
# 36              SOUTH OAKLAND         103.0
# 0                 SOUTH SHORE           0.0
# 74            SOUTHSIDE FLATS         277.0
# 67           SOUTHSIDE SLOPES         220.0
# 26              SPRING GARDEN          67.0
# 59       SPRING HILL-CITYVIEW         189.0
# 68        SQUIRREL HILL NORTH         242.0
# 89        SQUIRREL HILL SOUTH         802.0
# 75            STANTON HEIGHTS         278.0
# 8              STRIP DISTRICT          19.0
# 24                SUMMER HILL          64.0
# 27             SWISSHELM PARK          67.0
# 35            TERRACE VILLAGE          99.0
# 48    TROY HILL/HERR'S ISLAND         151.0
# 60                 UPPER HILL         191.0
# 39        UPPER LAWRENCEVILLE         119.0
# 5                    WEST END          14.0
# 33               WEST OAKLAND          93.0
# 51                   WESTWOOD         173.0
# 37                    WINDGAP         104.0
#
# [90 rows x 2 columns]
